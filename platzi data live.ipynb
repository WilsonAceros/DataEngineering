# %%
print ('Hola Mundo')

# %%
#Primitivos
integer_type=42
float_type=3.14159
bool_type=False
hex_type=0xff
oct_type=0o23
str_type='Wilson'

# %%
#Estructurados
from IPython.display import Image
Image('mysql_table_example.png')

# %%
#Semiestructurados
Image('html_markup_example.png')

# %% [markdown]
# NO ESTRUCTURADO
# HOLA MUNDO

# %%
import requests
response=requests.get('https://www.platzi.com')
response??
response.encoding='utf-8'
print(dir(response))
# Out:
# ['__attrs__', '__bool__', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__nonzero__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_content', '_content_consumed', '_next', 'apparent_encoding', 'close', 'connection', 'content', 'cookies', 'elapsed', 'encoding', 'headers', 'history', 'is_permanent_redirect', 'is_redirect', 'iter_content', 'iter_lines', 'json', 'links', 'next', 'ok', 'raise_for_status', 'raw', 'reason', 'request', 'status_code', 'text', 'url']

# %%
print(response.headers['Date'])
# Out:
# Wed, 02 Sep 2020 22:42:17 GMT

# %%
print(response.headers)
# Out:
# {'Date': 'Wed, 02 Sep 2020 22:42:17 GMT', 'Content-Type': 'text/html', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Vary': 'Accept-Encoding', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Methods': 'GET, POST', 'Access-Control-Allow-Headers': 'X-Requested-With,content-type,X-CSRFToken', 'Access-Control-Allow-Credentials': 'true', 'X-DNS-Prefetch-Control': 'off', 'X-Frame-Options': 'SAMEORIGIN', 'Strict-Transport-Security': 'max-age=86400; includeSubDomains', 'X-Download-Options': 'noopen', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '1; mode=block', 'X-Permitted-Cross-Domain-Policies': 'none', 'CF-Cache-Status': 'DYNAMIC', 'cf-request-id': '04f29541bb0000e5b3c9a62200000001', 'Expect-CT': 'max-age=604800, report-uri="https://report-uri.cloudflare.com/cdn-cgi/beacon/expect-ct"', 'Server': 'cloudflare', 'CF-RAY': '5ccabe49283de5b3-BOG', 'Content-Encoding': 'gzip'}

# %%
print(response.text)
# Out:
#     <!doctype html>
#       <html lang=es-CO>
#         <head>
#           <meta charset="UTF-8">
#
#           <meta name="viewport" content="width=device-width, initial-scale=1" />
#           <title>ðPlatzi: âCursos Online Profesionales de TecnologÃ­a</title>
#           <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-svg-core@1.2.28/styles.css">
#           <link rel="stylesheet" href="https://static.platzi.com/mf-landings/assets/home.ba6f988cfadc4279a500.css" type="text/css" />
#           <link rel="shortcut icon" href="//static.platzi.com/media/favicons/platzi_favicon.png" />
#           <link rel="icon" sizes="192x192" href="//static.platzi.com/media/favicons/platzi_favicon.png">
#           <link rel="alternate" type="application/rss+xml" title="RSS 2.0" href="" />
#
# ...

# %%
import bs4

soup=bs4.BeautifulSoup(response.text,'html.parser')
print(soup.title.text)
print(soup.select('meta[name=description]')[0])
# Out:
# 🚀Platzi: ‎Cursos Online Profesionales de Tecnología
# <meta content="Aprende desde cero a crear el futuro web con nuestros Cursos Online Profesionales de Tecnología. 🚀¡Cursos de Desarrollo, Diseño, Marketing y Negocios!" name="description"/>

# %%
import bs4

soup=bs4.BeautifulSoup(response.text,'html.parser')

courses_links=soup.select('.RecentCourses-item')
courses=[course.a['href'] for course in courses_links]

for course in courses:
    print(course)
# Out:
# /cursos/tecnicas-creatividad
# /cursos/ingles-practico-pronuncia
# /cursos/intermedio-ror-2020
# /cursos/zapier-2020
# /cursos/clasificacion-texto-2020
# /cursos/redshift-big-data-2020
# /cursos/html-css-2020
# /cursos/svelte-sapper-practico
# /cursos/woocommerce-2020
# /cursos/pronunciacion-intermedio
# /cursos/fundamentos-ecommerce
# /cursos/proyectos-pmbok
# /cursos/taller-principiantes
# /cursos/next-2020
# /cursos/productividad

# %%
import requests
import bs4

response.encoding='utf-8'
url='https://www.eltiempo.com'
response=requests.get(url)

#print(response.text)

soup=bs4.BeautifulSoup(response.text, 'html.parser')
news=soup.select('.title-container')

for item in news:
    print(f"Noticia: {item.text}")
# Out:
# Noticia:
# Fallas en procesamiento de pruebas covid dejarían millonarias pérdidas
# Noticia:
# ¿Por qué se está convocando a un paro nacional?
# Noticia:
# Covid-19: se registran 296 muertes más y 10.011 nuevos recuperados
# Noticia:
# 'Funcionario equivocado firmó deportación de Mancuso a Colombia'
# Noticia:
# Saab dice que encapuchados lo golpean para que firme extradición
# Noticia:
# Esta sería la nueva imagen del tercer sospechoso de la masacre de Cali
# Noticia:
# El contrato exorbitante que Messi tendría con su nuevo equipo
# Noticia:
# La increíble razón por la que Julian Alaphilippe ya no es el líder
# Noticia:
# VideoLe salió competencia a la campaña 'Free Uribe'
# Noticia:
# 'Uribe ha tenido por práctica cambiar su posición con la justicia': Cepeda
# Noticia:
# Viva Air critica el 'trato injusto' del Gobierno en crédito a Avianca
# Noticia:
# Trump incluye a fiscal de CPI en lista de sancionados en la que están Maduro y Eln
# Noticia:
# ...

# %%
import pandas as pd

series_test=pd.Series([100,200,300])
series_test
# Out:
# 0    100
# 1    200
# 2    300
# dtype: int64

# %%
series_test2=pd.Series({1999: 48, 2000: 65,2001: 89})
series_test2
# Out:
# 1999    48
# 2000    65
# 2001    89
# dtype: int64

# %% [markdown]
# DATA FRAMES

# %%
frame_test=pd.DataFrame({1999: [74,38,39],
                        2000: [34,32,32],
                        2001: [23,39,23]})
frame_test
# Out:
#    1999  2000  2001
# 0    74    34    23
# 1    38    32    39
# 2    39    32    23

# %%
frame_test2=pd.DataFrame([[74,38,39],
                        [34,32,32],
                        [23,39,23]],columns=[1999,2000,2001])
frame_test2
# Out:
#    1999  2000  2001
# 0    74    38    39
# 1    34    32    32
# 2    23    39    23

# %% [markdown]
# Read Data

# %%
import pandas as pd

#pd.options.display.max_rows=10
el_universal = pd.read_csv('eluniversal_2020_09_10_articles.csv',encoding='ISO-8859-1')
#el_universal.head()
el_universal.tail()
# Out:
#                                                  body  title  \
# 28  \r\nHace unos días el presidente Andrés Manuel...    NaN
# 29  \r\nLas sospechas de corrupción y tráfico de i...    NaN
# 30  \r\nEstimados Fanáticos Morenenses: Les juro q...    NaN
# 31                                                NaN    NaN
# 32                                                NaN    NaN
#
#                                                   url
# 28  http://www.eluniversal.com.mx/opinion/salvador...
# 29  http://www.eluniversal.com.mx/opinion/mario-ma...
# 30  http://www.eluniversal.com.mx/opinion/carlos-a...
# 31     https://www.eluniversal.com.mx/edicion-impresa
# 32  http://www.eluniversal.com.mx/autor-opinion/co...

# %% [markdown]
# INDEX AND SELECTION

# %%
#Dictionary like
el_universal['title']
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# 5    NaN
# 6    NaN
# 7    NaN
# 8    NaN
# 9    NaN
# 10   NaN
# 11   NaN
# 12   NaN
# 13   NaN
# 14   NaN
# 15   NaN
# 16   NaN
# 17   NaN
# 18   NaN
# 19   NaN
# 20   NaN
# 21   NaN
# 22   NaN
# 23   NaN
# 24   NaN
# 25   NaN
# 26   NaN
# 27   NaN
# 28   NaN
# 29   NaN
# 30   NaN
# 31   NaN
# 32   NaN
# Name: title, dtype: float64

# %%
el_universal['url']
# Out:
# 0                  http://www.eluniversal.com.mx/nacion
# 1     http://www.eluniversal.com.mx/nacion/cartel-ja...
# 2     http://www.eluniversal.com.mx/opinion/paola-fe...
# 3     https://www.viveusa.mx/destinos/expulsan-pasaj...
# 4     https://www.eluniversal.com.mx/nacion/organiza...
# 5     http://www.eluniversal.com.mx/nacion/pactan-va...
# 6     https://www.eluniversal.com.mx/nacion/presa-la...
# 7     http://www.eluniversal.com.mx/autor-opinion/ar...
# 8     http://www.eluniversal.com.mx/autor-opinion/ar...
# 9     http://www.eluniversal.com.mx/autor-opinion/co...
# 10    https://www.eluniversal.com.mx/nacion/amlo-sen...
# 11    http://www.eluniversal.com.mx/opinion/hector-d...
# 12    http://www.eluniversal.com.mx/autor-opinion/co...
# 13    http://www.eluniversal.com.mx/autor-opinion/co...
# 14    http://www.eluniversal.com.mx/edicion-impresa/...
# 15    http://www.eluniversal.com.mx/opinion/periodis...
# 16    https://www.eluniversal.com.mx/de-ultima/barba...
# ...

# %%
el_universal[['body','url']]
# Out:
#                                                  body  \
# 0                                                 NaN
# 1   \r\n\r\nAnte la dispersión de La Unión Tepito,...
# 2   \r\n\r\nA las y los mexicanos: La Cámara de Di...
# 3   \r\nUn adulto mayor fue expulsado de un vuelo ...
# 4   \r\nLa Unión Nacional de Trabajadores Agrícola...
# ..                                                ...
# 28  \r\nHace unos días el presidente Andrés Manuel...
# 29  \r\nLas sospechas de corrupción y tráfico de i...
# 30  \r\nEstimados Fanáticos Morenenses: Les juro q...
# 31                                                NaN
# 32                                                NaN
#
#                                                   url
# 0                http://www.eluniversal.com.mx/nacion
# 1   http://www.eluniversal.com.mx/nacion/cartel-ja...
# 2   http://www.eluniversal.com.mx/opinion/paola-fe...
# 3   https://www.viveusa.mx/destinos/expulsan-pasaj...
# ...

# %%
#numpy like

el_universal.iloc[10:15]
# Out:
#                                                  body  title  \
# 10  \r\nAl lamentar la muerte de una mujer tras la...    NaN
# 11  \r\nEn el lugar se localizaron 39 cartuchos de...    NaN
# 12                                                NaN    NaN
# 13                                                NaN    NaN
# 14                                                NaN    NaN
#
#                                                   url
# 10  https://www.eluniversal.com.mx/nacion/amlo-sen...
# 11  http://www.eluniversal.com.mx/opinion/hector-d...
# 12  http://www.eluniversal.com.mx/autor-opinion/co...
# 13  http://www.eluniversal.com.mx/autor-opinion/co...
# 14  http://www.eluniversal.com.mx/edicion-impresa/...

# %%
el_universal.iloc[32]
# Out:
# body                                                   NaN
# title                                                  NaN
# url      http://www.eluniversal.com.mx/autor-opinion/co...
# Name: 32, dtype: object

# %%
el_universal.iloc[15]['body']
# Out:
# '\r\n\r\nNos cuentan que tanto el gobierno mexicano como el laboratorio nacional Landsteiner Scientific fueron \x93madrugados\x94 por Fondo Ruso de Inversión Directa, pues aunque era un secreto a voces a nivel gubernamental y privado que la firma farmacéutica buscó un convenio con los rusos para acceder a la vacuna contra el coronavirus que genera Covid-19, no tenían pensado divulgar dicha información. \xa0En México, la Secretaría de Salud y la Secretaría de Relaciones Exteriores se aventaron la pelotita del tema una vez que se hizo público el tema del acuerdo privado para adquirir los 32 millones de dosis de vacunas para aplicarse entre los mexicanos. Fuentes de primer nivel aseguraron que el gobierno del presidente Andrés Manuel López Obrador sí sabía de esta operación realizada por iniciativa del laboratorio Landsteiner con Rusia para ser parte de la solución contra Covid-19. Lo importante, nos hacen ver, es que la información llega justo cuando el propio gobierno mexicano ha dich
# ...

# %%
el_universal.iloc[:5,0]
# Out:
# 0                                                  NaN
# 1    \r\n\r\nAnte la dispersión de La Unión Tepito,...
# 2    \r\n\r\nA las y los mexicanos: La Cámara de Di...
# 3    \r\nUn adulto mayor fue expulsado de un vuelo ...
# 4    \r\nLa Unión Nacional de Trabajadores Agrícola...
# Name: body, dtype: object

# %%
el_universal.loc[:,'body':'title']
# Out:
#                                                  body  title
# 0                                                 NaN    NaN
# 1   \r\n\r\nAnte la dispersión de La Unión Tepito,...    NaN
# 2   \r\n\r\nA las y los mexicanos: La Cámara de Di...    NaN
# 3   \r\nUn adulto mayor fue expulsado de un vuelo ...    NaN
# 4   \r\nLa Unión Nacional de Trabajadores Agrícola...    NaN
# ..                                                ...    ...
# 28  \r\nHace unos días el presidente Andrés Manuel...    NaN
# 29  \r\nLas sospechas de corrupción y tráfico de i...    NaN
# 30  \r\nEstimados Fanáticos Morenenses: Les juro q...    NaN
# 31                                                NaN    NaN
# 32                                                NaN    NaN
#
# [33 rows x 2 columns]

# %% [markdown]
# Data Wrangling

# %%
#1. Añadir newspapeer_uid al Dataframe

el_universal['newspaper_uid']='eluniversal'
el_universal
# Out:
#                                                  body  title  \
# 0                                                 NaN    NaN
# 1   \r\n\r\nAnte la dispersión de La Unión Tepito,...    NaN
# 2   \r\n\r\nA las y los mexicanos: La Cámara de Di...    NaN
# 3   \r\nUn adulto mayor fue expulsado de un vuelo ...    NaN
# 4   \r\nLa Unión Nacional de Trabajadores Agrícola...    NaN
# 5   \r\n\r\nSin la intervención del gobierno feder...    NaN
# 6   \r\nLa Guardia Nacional puso a disposición de ...    NaN
# 7                                                 NaN    NaN
# 8                                                 NaN    NaN
# 9                                                 NaN    NaN
# 10  \r\nAl lamentar la muerte de una mujer tras la...    NaN
# 11  \r\nEn el lugar se localizaron 39 cartuchos de...    NaN
# 12                                                NaN    NaN
# 13                                                NaN    NaN
# ...

# %%
#2. Obtener el host
from urllib.parse import urlparse

el_universal['host']=el_universal['url'].apply(lambda url: urlparse(url).netloc)

el_universal
# Out:
#                                                  body  title  \
# 0                                                 NaN    NaN
# 1   \r\n\r\nAnte la dispersión de La Unión Tepito,...    NaN
# 2   \r\n\r\nA las y los mexicanos: La Cámara de Di...    NaN
# 3   \r\nUn adulto mayor fue expulsado de un vuelo ...    NaN
# 4   \r\nLa Unión Nacional de Trabajadores Agrícola...    NaN
# 5   \r\n\r\nSin la intervención del gobierno feder...    NaN
# 6   \r\nLa Guardia Nacional puso a disposición de ...    NaN
# 7                                                 NaN    NaN
# 8                                                 NaN    NaN
# 9                                                 NaN    NaN
# 10  \r\nAl lamentar la muerte de una mujer tras la...    NaN
# 11  \r\nEn el lugar se localizaron 39 cartuchos de...    NaN
# 12                                                NaN    NaN
# 13                                                NaN    NaN
# ...

# %%
el_universal['host'].value_counts()
# Out:
# www.eluniversal.com.mx    32
# www.viveusa.mx             1
# Name: host, dtype: int64

# %% [markdown]
# MISSING DATA

# %%
#3. Rellenar datos faltantes
missing_titles_mask=el_universal['title'].isna()
missing_titles=(el_universal[missing_titles_mask]['url']
                    .str.extract(r'(?P<missing_titles>[^/]+)$')
                    .applymap(lambda title: title.split('-'))
                    .applymap(lambda title_word_list: ' '.join(title_word_list))
                )
missing_titles

el_universal.loc[missing_titles_mask,'title']=missing_titles.loc[:,'missing_titles']

# %% [markdown]
# Addtional Cleanup

# %%
#4. Añadir uid a las filas
import hashlib

uids=(el_universal
          .apply(lambda row: hashlib.md5(bytes(row['url'].encode())), axis=1)
        .apply(lambda hash_object: hash_object.hexdigest())
    )

el_universal['uid']=uids
el_universal.set_index('uid', inplace=True)
el_universal
# Out:
#                                                                                body  \
# uid
# d1c306d3311e161ac3d49a83fcf11267                                                NaN
# 5600e8724b38d78b2a35df6f8047f719  \r\n\r\nAnte la dispersión de La Unión Tepito,...
# c92a84103412eb48a30547103d0c49fd  \r\n\r\nA las y los mexicanos: La Cámara de Di...
# bed37f90dd1745bb0322e1208391ad7b  \r\nUn adulto mayor fue expulsado de un vuelo ...
# 9a3d856829d277193c55b348659901a3  \r\nLa Unión Nacional de Trabajadores Agrícola...
# ee3e7adb6e74815077e6b619432f0e16  \r\n\r\nSin la intervención del gobierno feder...
# 1eaa40448e6ab80a0b48ab78ed0fef1d  \r\nLa Guardia Nacional puso a disposición de ...
# 4f6ceab5da51bfc3a7db512b6024e9b2                                                NaN
# cc19729659e6a4bb7d245a22bf767f56                                                NaN
# d320f32b80de238913d90d1014a7dc92                                                NaN
# ...

# %%
stripped_body=(el_universal
               .apply(lambda row: row['body'], axis=1)
               .astype(str)#Define el tipo de dato como string
               .apply(lambda body: list(body))
               .apply(lambda letters: list(map(lambda letter: letter.replace('\n',''),letters)))
               .apply(lambda letters: list(map(lambda letter: letter.replace('\r',''),letters)))
               .apply(lambda letters: ''.join(letters))
                )

stripped_body
# Out:
# uid
# d1c306d3311e161ac3d49a83fcf11267                                                  nan
# 5600e8724b38d78b2a35df6f8047f719    Ante la dispersión de La Unión Tepito, el Cárt...
# c92a84103412eb48a30547103d0c49fd    A las y los mexicanos: La Cámara de Diputados ...
# bed37f90dd1745bb0322e1208391ad7b    Un adulto mayor fue expulsado de un vuelo de l...
# 9a3d856829d277193c55b348659901a3    La Unión Nacional de Trabajadores Agrícolas (U...
# ee3e7adb6e74815077e6b619432f0e16    Sin la intervención del gobierno federal, Rusi...
# 1eaa40448e6ab80a0b48ab78ed0fef1d    La Guardia Nacional puso a disposición de la F...
# 4f6ceab5da51bfc3a7db512b6024e9b2                                                  nan
# cc19729659e6a4bb7d245a22bf767f56                                                  nan
# d320f32b80de238913d90d1014a7dc92                                                  nan
# 3b3578492b6e8cf1d4a932958c6ce243    Al lamentar la muerte de una mujer tras la tom...
# ...

# %% [markdown]
# DATA ENRICHMENT

# %%
# 6 TOKENIZAR EL TITULO Y EL BODY
import nltk
from nltk.corpus import stopwords

#nltk.download('punkt')
#nltk.download('stopwords')
el_universal[el_universal.index.duplicated()]
el_universal=el_universal[~el_universal.index.duplicated()]

stop_words=set(stopwords.words('spanish'))

def tokenize_column(df,column_name):
    return (df
           .dropna()
           .apply(lambda row: nltk.word_tokenize(row[column_name]), axis=1)
           .apply(lambda tokens: list(filter(lambda token: token.isalpha(),tokens)))
           .apply(lambda tokens: list(map(lambda token: token.lower(), tokens)))
           .apply(lambda word_list: list(filter(lambda word: word not in stop_words, word_list)))
           .apply(lambda valid_word_list: len(valid_word_list))
           )

el_universal['n_tokens_title']=tokenize_column(el_universal,'title')
el_universal

el_universal['n_tokens_body']=tokenize_column(el_universal,'body')
el_universal
# Out:
#                                                                                body  \
# uid
# d1c306d3311e161ac3d49a83fcf11267                                                NaN
# 5600e8724b38d78b2a35df6f8047f719  \r\n\r\nAnte la dispersión de La Unión Tepito,...
# c92a84103412eb48a30547103d0c49fd  \r\n\r\nA las y los mexicanos: La Cámara de Di...
# bed37f90dd1745bb0322e1208391ad7b  \r\nUn adulto mayor fue expulsado de un vuelo ...
# 9a3d856829d277193c55b348659901a3  \r\nLa Unión Nacional de Trabajadores Agrícola...
# ee3e7adb6e74815077e6b619432f0e16  \r\n\r\nSin la intervención del gobierno feder...
# 1eaa40448e6ab80a0b48ab78ed0fef1d  \r\nLa Guardia Nacional puso a disposición de ...
# 4f6ceab5da51bfc3a7db512b6024e9b2                                                NaN
# cc19729659e6a4bb7d245a22bf767f56                                                NaN
# d320f32b80de238913d90d1014a7dc92                                                NaN
# ...

# %% [markdown]
# Duplicate Values

# %%
#Eliminar una columna
#el_universal=el_universal.drop([1],axis=1)
el_universal
# Out:
#                                                                                body  \
# uid
# d1c306d3311e161ac3d49a83fcf11267                                                NaN
# 5600e8724b38d78b2a35df6f8047f719  \r\n\r\nAnte la dispersión de La Unión Tepito,...
# c92a84103412eb48a30547103d0c49fd  \r\n\r\nA las y los mexicanos: La Cámara de Di...
# bed37f90dd1745bb0322e1208391ad7b  \r\nUn adulto mayor fue expulsado de un vuelo ...
# 9a3d856829d277193c55b348659901a3  \r\nLa Unión Nacional de Trabajadores Agrícola...
# ee3e7adb6e74815077e6b619432f0e16  \r\n\r\nSin la intervención del gobierno feder...
# 1eaa40448e6ab80a0b48ab78ed0fef1d  \r\nLa Guardia Nacional puso a disposición de ...
# 4f6ceab5da51bfc3a7db512b6024e9b2                                                NaN
# cc19729659e6a4bb7d245a22bf767f56                                                NaN
# d320f32b80de238913d90d1014a7dc92                                                NaN
# ...

# %%
#8. Eliminar duplicados
el_universal['url'].value_counts()
# Out:
# http://www.eluniversal.com.mx/opinion/carlos-alazraki/carta-dirigida-los-fanaticos-de-morena-pan-no-circo-si                          1
# https://www.viveusa.mx/destinos/expulsan-pasajero-vuelo-pedirle-azafata-cubrebocas                                                    1
# http://www.eluniversal.com.mx/autor-opinion/columnistas/luis-cardenas/en-la-mira                                                      1
# http://www.eluniversal.com.mx/autor-opinion/columnistas/carlos-loret-de-mola/historias-de-reportero                                   1
# http://www.eluniversal.com.mx/opinion/salvador-garcia-soto/el-doble-conflicto-de-chihuahua                                            1
# http://www.eluniversal.com.mx/autor-opinion/columnistas/periodistas-el-universal/bajo-reserva                                         1
# https://www.eluniversal.com.mx/de-ultima/barbara-de-regil-se-transforma-en-rubia-para-celebrar-con-su-hija                            1
# ...

# %%
el_universal['body'].value_counts()
# Out:
# \r\nLa Comisión Europea (UE) advirtió este jueves que no dudará en recurrir a acciones legales contra el controvertido proyecto de ley británico que revisa parcialmente los compromisos adoptados en el marco del Brexit.\r\nEn un comunicado, el vicepresidente de la Comisión, Maros Sefcovic, recordó que el Acuerdo de Retirada "contiene mecanismos y remedios legales para tratar violaciones a las obligaciones (...), que la Unión Europea no dudará en utilizar".\r\nEl funcionario apuntó que ese proyecto de ley "ha dañado seriamente la confianza" entre las partes y que "ahora cabe al gobierno británico restablecer esa confianza".\r\nPor ello formuló un llamado a Londres para que "retire esas medidas del proyecto de ley lo antes posible, y en cualquier caso antes del fin de mes".\r\n"La UE no acepta el argumento de que la intención del proyecto de ley es proteger el Acuerdo de Viernes Santo. De hecho, considera que hace lo opuesto", reza la nota de la Comisión Europea. \r\nEn la opinión de Se
# ...

# %%
el_universal['title'].value_counts()
# Out:
# pactan vacuna con rusia sin mediacion de la 4t                                               1
# edicion impresa                                                                              1
# nfl chiefs recibiran 16 mil aficionados en regreso de temporada                              1
# amlo senala exgobernadores del pri y madero en conflicto de presa la boquilla                1
# 10                                                                                           1
# como burro sin mecate                                                                        1
# en la mira                                                                                   1
# historias de reportero                                                                       1
# las cartas de alazraki                                                                       1
# el doble conflicto de chihuahua                                                              1
# ...

# %%
el_universal[el_universal['title']=='el populista']
# Out:
#                                                                                body  \
# uid
# 73ebf8efa3602e786542342c3994e662  \r\n\r\nDictadura: sistema de gobierno en el ...
#
#                                          title  \
# uid
# 73ebf8efa3602e786542342c3994e662  el populista
#
#                                                                                 url  \
# uid
# 73ebf8efa3602e786542342c3994e662  http://www.eluniversal.com.mx/opinion/luis-car...
#
#                                  newspaper_uid                    host    1  \
# uid
# 73ebf8efa3602e786542342c3994e662   eluniversal  www.eluniversal.com.mx  1.0
#
#                                   n_tokens_title
# uid
# 73ebf8efa3602e786542342c3994e662             1.0

# %%
#Para borrar el duplicado
#el_universal.drop_duplicates(subset=['title'],keep='first', implace=True)

# %%
#TABLA FINAL

el_universal
# Out:
#                                                                                body  \
# uid
# d1c306d3311e161ac3d49a83fcf11267                                                NaN
# 5600e8724b38d78b2a35df6f8047f719  \r\n\r\nAnte la dispersión de La Unión Tepito,...
# c92a84103412eb48a30547103d0c49fd  \r\n\r\nA las y los mexicanos: La Cámara de Di...
# bed37f90dd1745bb0322e1208391ad7b  \r\nUn adulto mayor fue expulsado de un vuelo ...
# 9a3d856829d277193c55b348659901a3  \r\nLa Unión Nacional de Trabajadores Agrícola...
# ee3e7adb6e74815077e6b619432f0e16  \r\n\r\nSin la intervención del gobierno feder...
# 1eaa40448e6ab80a0b48ab78ed0fef1d  \r\nLa Guardia Nacional puso a disposición de ...
# 4f6ceab5da51bfc3a7db512b6024e9b2                                                NaN
# cc19729659e6a4bb7d245a22bf767f56                                                NaN
# d320f32b80de238913d90d1014a7dc92                                                NaN
# ...

# %%
clean_el_universal = pd.read_csv('clean_eluniversal_2020_09_16_articles.csv',encoding='ISO-8859-1')
clean_el_universal
# Out:
#                                  uid  \
# 0   3a1d7e432250efc1e5269d1d9a8a97e0
# 1   3913c8a46adf27b67ef04ac06cb26d4e
# 2   ac1e577808d5ab908eff1a9990931028
# 3   a4eace51a8dab22fb9c7167ae0e008f8
# 4   8aaaff5e66923f092ac86604edff607d
# 5   5517cc2cfb6522ad227e444a08b81646
# 6   f859307c8913c22862270d2e00913737
# 7   c9476c5e5db885e34919f12f482ba207
# 8   3c464d59c3a74bbd2b1b035ada1cdb34
# 9   dcdefeba6e4c6905af58a3b68f8bee94
# 10  16de1906e7385a34e5a437496888df5f
# 11  0306c0a0ce19049f272f2da989c47012
# 12  0959f12c90e33375213ca66473c491ef
# 13  f27ab13de651c6d86736832a9a2ab6cb
# 14  d1c306d3311e161ac3d49a83fcf11267
# 15  cc72cfd6223f163fef302e889501d0f8
# 16  0a7a4226c0359e0b3108798c3f04ce07
# 17  9f9f8dffa14704dd003e8ec532662f54
# 18  d28986f6bcb936aef9115d2fc91e8d17
# 19  5fafe56756786968e7d1cd40bb727108
# 20  f7a46af5aea277666fc4dd0a82f27379
# 21  31ba68063395b91b44bbe771314bfec0
# 22  fe18380beed0dd1419d39676b4286cf8
# 23  a387165aa27081ab82b1bc1d1fb9bb4e
# ...

# %%
clean_el_universal.describe()
# Out:
#        n_tokens_title  n_tokens_body
# count       37.000000      37.000000
# mean         4.108108     170.081081
# std          2.611766     157.999363
# min          0.000000       1.000000
# 25%          2.000000       1.000000
# 50%          3.000000     180.000000
# 75%          6.000000     277.000000
# max         10.000000     557.000000

# %%
clean_el_universal.loc[clean_el_universal['n_tokens_title']==0]
# Out:
#                                  uid body title  \
# 13  f27ab13de651c6d86736832a9a2ab6cb  NaN    16
#
#                                                   url newspaper_uid  \
# 13  http://www.eluniversal.com.mx/edicion-impresa/...   eluniversal
#
#                       host  n_tokens_title  n_tokens_body
# 13  www.eluniversal.com.mx               0              1

# %%
# %matplotlib inline

# %%
clean_el_universal['n_tokens_title'].plot(style='k.')

# %%
clean_el_universal['n_tokens_body'].plot(style='r.')

# %%
all_newspapers=pd.concat([clean_el_universal])
grouped=all_newspapers.groupby('newspaper_uid')
grouped.hist()
# Out:
# newspaper_uid
# eluniversal    [[AxesSubplot(0.125,0.125;0.336957x0.755), Axe...
# dtype: object

# %%
grouped['n_tokens_body'].agg(['min','mean','max'])
# Out:
#                min        mean  max
# newspaper_uid
# eluniversal      1  170.081081  557

# %%
grouped.plot()
# Out:
# newspaper_uid
# eluniversal    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object
